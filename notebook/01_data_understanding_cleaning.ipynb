# %% [markdown]
# # NETFLIX EDA - Movies and TV Shows

# %%
# Libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
FILE_PATH = "/home/gustavo/repos/netflix-eda/data/raw/netflix_data.csv"

df = pd.read_csv(FILE_PATH)

# %% [markdown]
# ## Etapa 1 - Entendimiento del dataset

# %%
df.head(5)
# Out:
#   show_id     type  title           director  \
# 0      s2    Movie   7:19  Jorge Michel Grau
# 1      s3    Movie  23:59       Gilbert Chan
# 2      s4    Movie      9        Shane Acker
# 3      s5    Movie     21     Robert Luketic
# 4      s6  TV Show     46        Serdar Akar
#
#                                                 cast        country  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 2  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 3  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 4  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#           date_added  release_year  duration  \
# 0  December 23, 2016          2016        93
# 1  December 20, 2018          2011        78
# 2  November 16, 2017          2009        80
# 3    January 1, 2020          2008       123
# 4       July 1, 2017          2016         1
#
#                                          description             genre
# 0  After a devastating earthquake hits Mexico Cit...            Dramas
# 1  When an army recruit is found dead, his fellow...     Horror Movies
# 2  In a postapocalyptic world, rag-doll robots hi...            Action
# 3  A brilliant group of students become card-coun...            Dramas
# 4  A genetics professor experiments with a treatm...  International TV

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   str
#  1   type          4812 non-null   str
#  2   title         4812 non-null   str
#  3   director      4812 non-null   str
#  4   cast          4812 non-null   str
#  5   country       4812 non-null   str
#  6   date_added    4812 non-null   str
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   str
#  10  genre         4812 non-null   str
# dtypes: int64(2), str(9)
# memory usage: 413.7 KB

# %%
df.shape
# Out:
# (4812, 11)

# %%
# NaN values?

df.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# duration        0
# description     0
# genre           0
# dtype: int64

# %%
# null values?

df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# duration        0
# description     0
# genre           0
# dtype: int64

# %% [markdown]
# ## ETAPA 2 — Limpieza de datos

# %%
# Identificar si existen valores duplicados

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Transformar la columan date_added

df['date_added'] = pd.to_datetime(df['date_added'], format='mixed', errors='coerce')

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   str
#  1   type          4812 non-null   str
#  2   title         4812 non-null   str
#  3   director      4812 non-null   str
#  4   cast          4812 non-null   str
#  5   country       4812 non-null   str
#  6   date_added    4812 non-null   datetime64[us]
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   str
#  10  genre         4812 non-null   str
# dtypes: datetime64[us](1), int64(2), str(8)
# memory usage: 413.7 KB

# %%
# Crear columna para año y mes del dataset

df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month

df.head(2)
# Out:
#   show_id   type  title           director  \
# 0      s2  Movie   7:19  Jorge Michel Grau
# 1      s3  Movie  23:59       Gilbert Chan
#
#                                                 cast    country date_added  \
# 0  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico 2016-12-23
# 1  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore 2018-12-20
#
#    release_year  duration                                        description  \
# 0          2016        93  After a devastating earthquake hits Mexico Cit...
# 1          2011        78  When an army recruit is found dead, his fellow...
#
#            genre  year_added  month_added
# 0         Dramas        2016           12
# 1  Horror Movies        2018           12

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       4812 non-null   str
#  1   type          4812 non-null   str
#  2   title         4812 non-null   str
#  3   director      4812 non-null   str
#  4   cast          4812 non-null   str
#  5   country       4812 non-null   str
#  6   date_added    4812 non-null   datetime64[us]
#  7   release_year  4812 non-null   int64
#  8   duration      4812 non-null   int64
#  9   description   4812 non-null   str
#  10  genre         4812 non-null   str
#  11  year_added    4812 non-null   int32
#  12  month_added   4812 non-null   int32
# dtypes: datetime64[us](1), int32(2), int64(2), str(8)
# memory usage: 451.3 KB

# %%
# Verificación columna 'type'

df['type'].unique()
# Out:
# <StringArray>
# ['Movie', 'TV Show']
# Length: 2, dtype: str

# %%
# Verificación columna 'release_year'
df['release_year'].unique()
# Out:
# array([2016, 2011, 2009, 2008, 2019, 1997, 2017, 2018, 2014, 2020, 2015,
#        2010, 2005, 2012, 2006, 2013, 2000, 1989, 2004, 1977, 1971, 1993,
#        2007, 1998, 1988, 1996, 2002, 1986, 1990, 1979, 1980, 1974, 2001,
#        1999, 1966, 1991, 1982, 1994, 2003, 1995, 1978, 1992, 1972, 1975,
#        1973, 1967, 1960, 1981, 1958, 1976, 2021, 1968, 1956, 1985, 1965,
#        1984, 1983, 1987, 1945, 1946, 1962, 1969, 1955, 1963, 1964, 1942,
#        1954, 1970, 1947, 1944, 1959])

# %%
print(df['duration'].max())
print(df['duration'].min())
print(df['duration'].mean())
# Out:
# 253
# 1
# 99.56670822942644

# %%
df[df['duration'] == 1]
# Out:
#      show_id     type                         title  \
# 4         s6  TV Show                            46
# 94      s133  TV Show                     7 (Seven)
# 151     s219  TV Show               A Queen Is Born
# 181     s261  TV Show                      A.I.C.O.
# 197     s277  TV Show                  Abby Hatcher
# ...      ...      ...                           ...
# 4410   s7089  TV Show          Til Death Do Us Part
# 4427   s7119  TV Show                   To the Lake
# 4536   s7314  TV Show  Unabomber - In His Own Words
# 4580   s7386  TV Show                       Valeria
# 4645   s7493  TV Show                Watership Down
#
#                                                director  \
# 4                                           Serdar Akar
# 94                                          Nizar Shafi
# 151                                        Carla Barros
# 181                                       Kazuya Murata
# 197                                         Kyran Kelly
# ...                                                 ...
# 4410  Cho Li, Chen Hung-yi, Weica Wang, Liu Bang-yao...
# 4427                                   Pavel Kostomarov
# 4536                                        Mick Grogan
# 4580                                      Inma Torrente
# 4645                                         Noam Murro
#
#                                                    cast         country  \
# 4     Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...          Turkey
# 94    Rahman, Havish, Regina Cassandra, Nandita Swet...           India
# 151                       Gloria Groove, Alexia Twister          Brazil
# 181   Haruka Shiraishi, Yusuke Kobayashi, Makoto Fur...           Japan
# 197   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...   United States
# ...                                                 ...             ...
# 4410  Wen Chen-ling, River Huang, Lin He-xuan, Phoeb...          Taiwan
# 4427  Viktoriya Isakova, Kirill Käro, Aleksandr Roba...          Russia
# 4536                                      Ted Kaczynski          Canada
# 4580  Diana Gómez, Silma López, Paula Malia, Teresa ...           Spain
# 4645  James McAvoy, Nicholas Hoult, John Boyega, Ben...  United Kingdom
#
#      date_added  release_year  duration  \
# 4    2017-07-01          2016         1
# 94   2019-07-30          2019         1
# 151  2020-11-11          2020         1
# 181  2018-03-09          2018         1
# 197  2020-07-01          2019         1
# ...         ...           ...       ...
# 4410 2019-08-15          2019         1
# 4427 2020-10-07          2020         1
# 4536 2020-02-22          2018         1
# 4580 2020-05-08          2020         1
# 4645 2018-12-23          2018         1
#
#                                             description             genre  \
# 4     A genetics professor experiments with a treatm...  International TV
# 94    Multiple women report their husbands as missin...          TV Shows
# 151   Gloria Groove and Alexia Twister make drag dre...  International TV
# 181   Everything Aiko knew was a lie. Now she's join...      Anime Series
# 197   A big-hearted girl helps her Fuzzly friends wh...              Kids
# ...                                                 ...               ...
# 4410  Based on the speculative short stories of Mirr...  International TV
# 4427  Facing the end of civilization when a terrifyi...  International TV
# 4536  The CIA attempts to turn Ted Kaczynski, aka th...          Crime TV
# 4580  A writer in creative and marital crises finds ...  International TV
# 4645  A warren of rabbits battles many threats on th...        British TV
#
#       year_added  month_added
# 4           2017            7
# 94          2019            7
# 151         2020           11
# 181         2018            3
# 197         2020            7
# ...          ...          ...
# 4410        2019            8
# 4427        2020           10
# 4536        2020            2
# 4580        2020            5
# 4645        2018           12
#
# [97 rows x 13 columns]

# %%
# Verificación columna 'country'

countries = df['country'].unique()
countries = countries.tolist()
countries.sort()
print(countries)
# Out:
# ['Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belgium', 'Brazil', 'Bulgaria', 'Cambodia', 'Canada', 'Chile', 'China', 'Colombia', 'Croatia', 'Czech Republic', 'Denmark', 'Egypt', 'Finland', 'France', 'Georgia', 'Germany', 'Ghana', 'Guatemala', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Kenya', 'Kuwait', 'Lebanon', 'Malaysia', 'Mexico', 'Namibia', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway', 'Pakistan', 'Paraguay', 'Peru', 'Philippines', 'Poland', 'Portugal', 'Romania', 'Russia', 'Saudi Arabia', 'Serbia', 'Singapore', 'Slovenia', 'Somalia', 'South Africa', 'South Korea', 'Soviet Union', 'Spain', 'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'United Arab', 'United Kingdom', 'United States', 'Uruguay', 'Venezuela', 'Vietnam', 'Zimbabwe']
